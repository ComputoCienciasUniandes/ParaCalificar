# %% [markdown]
# # Preference of Programming Language

# %%
import numpy as np
import pandas as pd 
import numpy as np 
import scipy 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from pandas.tools.plotting import scatter_matrix
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA

df = pd.read_csv("multipleChoiceResponses.csv", low_memory=False) #Import data
df = df[1:]

#Some interesting Variables
Gender = df['Q1']
Age = df['Q2']
Country = df['Q3']
LevEd = df['Q4']
Major = df['Q5']
Industry = df['Q7']
Exp = df['Q8']
Income = df['Q9']
ML_Business = df['Q10']

#Important at work
Business = df['Q11_Part_1']
ML_Service = df['Q11_Part_2']
DataInfras = df['Q11_Part_3']
Exploration = df['Q11_Part_4']
Research = df['Q11_Part_5']

#Tools
Basic = df['Q12_Part_1_TEXT']
Advanced = df['Q12_Part_2_TEXT']
Intelligence = df['Q12_Part_3_TEXT']
Local_Envir = df['Q12_Part_4_TEXT']

#Integrated Development Environments
Jupyter_Python = df['Q13_Part_1']
RStudio = df['Q13_Part_2']
PyCharm = df['Q13_Part_3']
VSC = df['Q13_Part_4']
Atom = df['Q13_Part_6']
MATLAB_E = df['Q13_Part_7']
Vim = df['Q13_Part_11']
Spyder =df['Q13_Part_13']

#Languages
Python = df['Q16_Part_1']
R = df['Q16_Part_2']
SQL = df['Q16_Part_3']
Bash = df['Q16_Part_4']
Java = df['Q16_Part_5']
Javascript = df['Q16_Part_6']
VB = df['Q16_Part_7']
C = df['Q16_Part_8']
MATLAB_L = df['Q16_Part_9']
Julia = df['Q16_Part_11']
PHP = df['Q16_Part_14']
Ruby = df['Q16_Part_15']
STATA = df['Q16_Part_16']

#Spending Time
Collect = df['Q34_Part_1']
Cleaning = df['Q34_Part_2']
Visualizing = df['Q34_Part_3']
Modelling = df['Q34_Part_4']
Producing = df['Q34_Part_5']

# %%
plt.figure(figsize=(20,10))
plt.subplots_adjust(hspace=1.0)

plt.subplot(3,3,1)
Gender.value_counts().plot(kind='bar')
plt.title('Gender')
plt.subplot(3,3,2)
Age.value_counts().plot(kind='bar')
plt.title('Age')
plt.subplot(3,3,3)
Country.value_counts().plot(kind='bar')
plt.title('Country')
plt.subplot(3,3,4)
LevEd.value_counts().plot(kind='bar')
plt.title('Education')
plt.subplot(3,3,5)
Major.value_counts().plot(kind='bar')
plt.title('Major')
plt.subplot(3,3,6)
Exp.value_counts().plot(kind='bar')
plt.title('Experience')
plt.subplot(3,3,7)
Income.value_counts().plot(kind='bar')
plt.title('Salary')
# Out:
# Text(0.5,1,'Salary')

# %%
X = df[['Q1','Q2','Q3','Q4','Q5','Q7','Q8','Q10']].values
mms = MinMaxScaler()
mms.fit(X)
Xtrans = mms.transform(X)

#K-Means
K=10
SSD = []
Acum = []
R = range(1,K,1)

C = 0
for i in R:
    km = KMeans(n_clusters=i).fit(Xtrans)
    SSD.append(km.inertia_)
    C+=km.inertia_
    Acum.append(C)
    
    
plt.figure(figsize=(12,6))
plt.suptitle("(K-Means Clustering)", fontsize=20)

plt.subplot(1,2,1)
plt.title("Optimal k, K-Cluster - Dengue")
plt.xlabel("k (Number of Clusters)")
plt.ylabel("Explained Variance Ratio")
plt.ylim(0,1)
plt.plot(R, SSD/np.sum(SSD), color="darkgreen")
plt.subplot(1,2,2)
plt.title("Optimal k, K-Cluster - Dengue")
plt.xlabel("k (Number of Clusters)")
plt.ylabel("Cumulative Explained Variance Ratio")
plt.plot(R, Acum/np.sum(SSD), color="darkgreen")
plt.ylim(0,1)

print("Optimal Cluster=2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-99e9e4929e34> in <module>()
#       1 X = df[['Q1','Q2','Q3','Q4','Q5','Q7','Q8','Q10']].values
#       2 mms = MinMaxScaler()
# ----> 3 mms.fit(X)
#       4 Xtrans = mms.transform(X)
#       5
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     306         # Reset internal state before fitting
#     307         self._reset()
# --> 308         return self.partial_fit(X, y)
#     309
#     310     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     332
#     333         X = check_array(X, copy=self.copy, warn_on_dtype=True,
# --> 334                         estimator=self, dtype=FLOAT_DTYPES)
#     335
#     336         data_min = np.min(X, axis=0)
#
# ...
